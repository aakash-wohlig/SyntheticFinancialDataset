# %% [markdown]
# # Synthetic Financial Datasets For Fraud Detection

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('SyntheticFinancialDataset.csv')

# %% [markdown]
# ### Basic Stas

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %% [markdown]
# ### Transcation Type

# %%
df_new = df.copy()

df_new['type1'] = np.nan

df_new.loc[(df.nameOrig.str.contains('C')) & (df.nameDest.str.contains('C')), 'type1'] = 'CC'
df_new.loc[(df.nameOrig.str.contains('C')) & (df.nameDest.str.contains('M')), 'type1'] = 'CM'
df_new.loc[(df.nameOrig.str.contains('M')) & (df.nameDest.str.contains('C')), 'type1'] = 'MC'
df_new.loc[(df.nameOrig.str.contains('M')) & (df.nameDest.str.contains('M')), 'type1'] = 'MM'

df_new
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud type1
# 0                     0    CM
# 1                     0    CM
# 2                     0    CC
# 3                     0    CC
# 4                     0    CM
# ...                 ...   ...
# 6362615               0    CC
# 6362616               0    CC
# 6362617               0    CC
# 6362618               0    CC
# 6362619               0    CC
#
# [6362620 rows x 12 columns]

# %%
df_new.type1.value_counts()
# Out:
# CC    4211125
# CM    2151495
# Name: type1, dtype: int64

# %% [markdown]
# ### ` Hence dataset has only two types of transactions (C to C) & (C to M)`

# %%
Fraud = df_new[df_new.isFraud == 1]
Valid = df_new[df_new.isFraud == 0]

print(f'''Fraud Transaction by type1\n{Fraud.type1.value_counts()}\n\n
Valid Transactionby type1\n{Valid.type1.value_counts()}''')
# Out:
# Fraud Transaction by type1
# CC    8213
# Name: type1, dtype: int64
#
#
# Valid Transactionby type1
# CC    4202912
# CM    2151495
# Name: type1, dtype: int64

# %%
Fraud = Fraud.drop('type1', axis=1)
Valid = Valid.drop('type1', axis=1)
df_new = df_new.drop('type1', axis=1)
df_new
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %% [markdown]
# ### `Hence Fraud occur only in C to C type transaction `

# %%
print(f'''Fraud Transaction by type1\n{Fraud.type.value_counts()}\n\n
Valid Transactionby type1\n{Valid.type.value_counts()}''')
# Out:
# Fraud Transaction by type1
# CASH_OUT    4116
# TRANSFER    4097
# Name: type, dtype: int64
#
#
# Valid Transactionby type1
# CASH_OUT    2233384
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     528812
# DEBIT         41432
# Name: type, dtype: int64

# %% [markdown]
# ### `Hence Fraud only occur in Transfer & Cash out`

# %%
Valid = Valid[(Valid.type == 'CASH_OUT') & (Valid.type == 'TRANSFER')]
df_new = df_new[(df_new.type == 'CASH_OUT') | (df_new.type == 'TRANSFER')]

# %%
wrong_org_bal = sum(df.oldbalanceOrg - df.amount != df.newbalanceOrig) 
wrong_des_bal = sum(df.oldbalanceDest + df.amount != df.newbalanceDest)

print(f'''% Error in giving Money: {round(wrong_org_bal/len(df), 2) * 100}
% Error in receiving Money: {round(wrong_des_bal/len(df), 2) * 100}''')
# Out:
# % Error in giving Money: 85.0
# % Error in receiving Money: 74.0

# %%
df_new[df_new.amount > df_new.oldbalanceOrg]
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 15          1  CASH_OUT  229133.94   C905080434       15325.00
# 19          1  TRANSFER  215310.30  C1670993182         705.00
# 24          1  TRANSFER  311685.89  C1984094095       10835.00
# 42          1  CASH_OUT  110414.71   C768216420       26845.41
# 47          1  CASH_OUT   56953.90  C1570470538        1942.02
# ...       ...       ...        ...          ...            ...
# 6362313   718  CASH_OUT  111963.72  C1438119383        4514.00
# 6362317   718  CASH_OUT  317177.48   C857156502         170.00
# 6362320   718  CASH_OUT  159188.22   C691808084        3859.00
# 6362321   718  CASH_OUT  186273.84   C102120699      168046.00
# 6362322   718  TRANSFER   82096.45   C614459560       13492.00
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 15                  0.0   C476402209         5083.00        51513.44        0
# 19                  0.0  C1100439041        22425.00            0.00        0
# 24                  0.0   C932583850         6267.00      2719172.89        0
# 42                  0.0  C1509514333       288800.00         2415.16        0
# 47                  0.0   C824009085        70253.00        64106.18        0
# ...                 ...          ...             ...             ...      ...
# 6362313             0.0    C99772923       154925.27       266888.99        0
# 6362317             0.0   C784108220       345042.13       662219.61        0
# 6362320             0.0  C1818183087            0.00       159188.22        0
# 6362321             0.0  C1515639522        24893.67       211167.51        0
# 6362322             0.0   C855350324            0.00        82096.45        0
#
#          isFlaggedFraud
# 15                    0
# 19                    0
# 24                    0
# 42                    0
# 47                    0
# ...                 ...
# 6362313               0
# 6362317               0
# 6362320               0
# 6362321               0
# 6362322               0
#
# [2488634 rows x 11 columns]

# %% [markdown]
# ### `Check for negative numbers`

# %%
relevant_cols = df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest"]].values.flatten()

# %%
num_neg_amt = sum(n < 0 for n in relevant_cols)
num_neg_amt
# Out:
# 0

# %% [markdown]
# ### `Logically Invalid Transactions`

# %%
sum(df.amount > df.oldbalanceOrg)
# Out:
# 4079080

# %%
sum(df.amount > df.newbalanceDest)
# Out:
# 2661141

# %%
df_new.head()
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2      1  TRANSFER     181.00  C1305486145          181.0             0.0
# 3      1  CASH_OUT     181.00   C840083671          181.0             0.0
# 15     1  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19     1  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24     1  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0

# %%
df_new.shape
# Out:
# (2770409, 11)

# %%
df_new['errorbalanceOrg'] = df_new.newbalanceOrig + df_new.amount - df_new.oldbalanceOrg
df_new['errorbalanceDest'] = df_new.oldbalanceDest + df_new.amount - df_new.newbalanceDest

# %%
df_new
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 15          1  CASH_OUT   229133.94   C905080434       15325.00
# 19          1  TRANSFER   215310.30  C1670993182         705.00
# 24          1  TRANSFER   311685.89  C1984094095       10835.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# 3                   0.0    C38997010        21182.00            0.00        1
# 15                  0.0   C476402209         5083.00        51513.44        0
# 19                  0.0  C1100439041        22425.00            0.00        0
# 24                  0.0   C932583850         6267.00      2719172.89        0
# ...                 ...          ...             ...             ...      ...
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud  errorbalanceOrg  errorbalanceDest
# 2                     0             0.00      1.810000e+02
# 3                     0             0.00      2.136300e+04
# 15                    0        213808.94      1.827035e+05
# 19                    0        214605.30      2.377353e+05
# 24                    0        300850.89     -2.401220e+06
# ...                 ...              ...               ...
# 6362615               0             0.00      0.000000e+00
# 6362616               0             0.00      6.311409e+06
# 6362617               0             0.00      1.000000e-02
# 6362618               0             0.00      8.500025e+05
# 6362619               0             0.00      9.313226e-10
#
# [2770409 rows x 13 columns]

# %%
df_new[df_new.errorbalanceOrg > 0]
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 15          1  CASH_OUT    229133.94   C905080434       15325.00
# 19          1  TRANSFER    215310.30  C1670993182         705.00
# 24          1  TRANSFER    311685.89  C1984094095       10835.00
# 42          1  CASH_OUT    110414.71   C768216420       26845.41
# 47          1  CASH_OUT     56953.90  C1570470538        1942.02
# ...       ...       ...          ...          ...            ...
# 6362321   718  CASH_OUT    186273.84   C102120699      168046.00
# 6362322   718  TRANSFER     82096.45   C614459560       13492.00
# 6362460   730  TRANSFER  10000000.00  C2140038573    17316255.05
# 6362462   730  TRANSFER   7316255.05  C1869569059    17316255.05
# 6362584   741  TRANSFER   5674547.89   C992223106     5674547.89
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 15                 0.00   C476402209         5083.00        51513.44        0
# 19                 0.00  C1100439041        22425.00            0.00        0
# 24                 0.00   C932583850         6267.00      2719172.89        0
# 42                 0.00  C1509514333       288800.00         2415.16        0
# 47                 0.00   C824009085        70253.00        64106.18        0
# ...                 ...          ...             ...             ...      ...
# 6362321            0.00  C1515639522        24893.67       211167.51        0
# 6362322            0.00   C855350324            0.00        82096.45        0
# 6362460     17316255.05  C1395467927            0.00            0.00        1
# 6362462     17316255.05  C1861208726            0.00            0.00        1
# 6362584      5674547.89  C1366804249            0.00            0.00        1
#
#          isFlaggedFraud  errorbalanceOrg  errorbalanceDest
# 15                    0        213808.94         182703.50
# 19                    0        214605.30         237735.30
# 24                    0        300850.89       -2401220.00
# 42                    0         83569.30         396799.55
# 47                    0         55011.88          63100.72
# ...                 ...              ...               ...
# 6362321               0         18227.84              0.00
# 6362322               0         68604.45              0.00
# 6362460               1      10000000.00       10000000.00
# 6362462               1       7316255.05        7316255.05
# 6362584               1       5674547.89        5674547.89
#
# [2504585 rows x 13 columns]

# %%
df_new[df_new.errorbalanceDest > 0]
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 15          1  CASH_OUT   229133.94   C905080434       15325.00
# 19          1  TRANSFER   215310.30  C1670993182         705.00
# 42          1  CASH_OUT   110414.71   C768216420       26845.41
# ...       ...       ...         ...          ...            ...
# 6362614   743  TRANSFER   339682.13  C2013999242      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# 3                   0.0    C38997010        21182.00            0.00        1
# 15                  0.0   C476402209         5083.00        51513.44        0
# 19                  0.0  C1100439041        22425.00            0.00        0
# 42                  0.0  C1509514333       288800.00         2415.16        0
# ...                 ...          ...             ...             ...      ...
# 6362614             0.0  C1850423904            0.00            0.00        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud  errorbalanceOrg  errorbalanceDest
# 2                     0             0.00      1.810000e+02
# 3                     0             0.00      2.136300e+04
# 15                    0        213808.94      1.827035e+05
# 19                    0        214605.30      2.377353e+05
# 42                    0         83569.30      3.967996e+05
# ...                 ...              ...               ...
# 6362614               0             0.00      3.396821e+05
# 6362616               0             0.00      6.311409e+06
# 6362617               0             0.00      1.000000e-02
# 6362618               0             0.00      8.500025e+05
# 6362619               0             0.00      9.313226e-10
#
# [550086 rows x 13 columns]

# %%
fraud = df_new[df_new["isFraud"] == 1]
valid = df_new[df_new["isFraud"] == 0]

# %%
fraud.head()
# Out:
#      step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2       1  TRANSFER    181.0  C1305486145          181.0             0.0
# 3       1  CASH_OUT    181.0   C840083671          181.0             0.0
# 251     1  TRANSFER   2806.0  C1420196421         2806.0             0.0
# 252     1  CASH_OUT   2806.0  C2101527076         2806.0             0.0
# 680     1  TRANSFER  20128.0   C137533655        20128.0             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2     C553264065             0.0             0.0        1               0
# 3      C38997010         21182.0             0.0        1               0
# 251   C972765878             0.0             0.0        1               0
# 252  C1007251739         26202.0             0.0        1               0
# 680  C1848415041             0.0             0.0        1               0
#
#      errorbalanceOrg  errorbalanceDest
# 2                0.0             181.0
# 3                0.0           21363.0
# 251              0.0            2806.0
# 252              0.0           29008.0
# 680              0.0           20128.0

# %% [markdown]
# ## `Error Balance Stats`

# %%
fraud.errorbalanceOrg.describe()
# Out:
# count    8.213000e+03
# mean     1.069233e+04
# std      2.651461e+05
# min     -7.450581e-09
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+07
# Name: errorbalanceOrg, dtype: float64

# %%
valid.errorbalanceOrg.describe()
# Out:
# count    2.762196e+06
# mean     2.868035e+05
# std      8.763752e+05
# min     -1.000000e-02
# 25%      5.261343e+04
# 50%      1.442008e+05
# 75%      2.804663e+05
# max      9.244552e+07
# Name: errorbalanceOrg, dtype: float64

# %%
fraud.errorbalanceDest.describe()
# Out:
# count    8.213000e+03
# mean     7.325093e+05
# std      1.867748e+06
# min     -8.875516e+06
# 25%      0.000000e+00
# 50%      2.231460e+03
# 75%      4.427220e+05
# max      1.000000e+07
# Name: errorbalanceDest, dtype: float64

# %%
valid.errorbalanceDest.describe()
# Out:
# count    2.762196e+06
# mean    -3.091033e+04
# std      5.840943e+05
# min     -7.588573e+07
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.977761e+06
# Name: errorbalanceDest, dtype: float64

# %%
ax = plt.subplot()

fplot = fraud.plot(x="errorbalanceOrg",y="errorbalanceDest",color="red",kind="scatter", \
                   ax=ax,label="Fraudulent transactions")
plt.title("errorBalanceOrg vs errorBalanceDest")
plt.show()

# %%
ax = plt.subplot()

vplot = valid.plot(x="errorbalanceOrg",y="errorbalanceDest",color="green",kind="scatter",\
                   alpha=0.01,ax=ax,label="Valid transactions")
plt.title("errorBalanceOrg vs errorBalanceDest")
plt.show()

# %%
ax = plt.subplot()

fplot = fraud.plot(x="errorbalanceOrg",y="errorbalanceDest",color="red",kind="scatter", \
                   ax=ax,label="Fraudulent transactions")
vplot = valid.plot(x="errorbalanceOrg",y="errorbalanceDest",color="green",kind="scatter",\
                   alpha=0.01,ax=ax,label="Valid transactions")

plt.title("errorBalanceOrg vs errorBalanceDest")
plt.show()

# %%
print(f'''Fraud Transaction
Original > 0:    { len(fraud[fraud.errorbalanceOrg > 0]) / len(fraud) }
Destination > 0: { len(fraud[fraud.errorbalanceDest > 0]) / len(fraud) }

Valid Transaction
Original > 0:    { len(valid[valid.errorbalanceOrg > 0]) / len(valid) }
Destination > 0: { len(valid[valid.errorbalanceDest > 0]) / len(valid) }
''')
# Out:
# Fraud Transaction
# Original > 0:    0.006331425788384269
# Destination > 0: 0.5712894192134421
#
# Valid Transaction
# Original > 0:    0.9067180605576143
# Destination > 0: 0.19744942067832985

# %%
fraud_transfer = fraud[fraud['type'] == 'TRANSFER']
fraud_cash_out = fraud[fraud['type'] == 'CASH_OUT']

# %%
fraud_transfer.nameDest.isin(fraud_cash_out.nameOrig).any()
# Out:
# False

# %% [markdown]
# ### `getting rid of nameOrig & nameDest column`

# %%
names = ["nameOrig","nameDest"]
fraud = fraud.drop(names, 1)
valid = valid.drop(names,1)
df_new = df_new.drop(names,1)

# %%
df_new
# Out:
#          step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 2           1  TRANSFER      181.00         181.00             0.0
# 3           1  CASH_OUT      181.00         181.00             0.0
# 15          1  CASH_OUT   229133.94       15325.00             0.0
# 19          1  TRANSFER   215310.30         705.00             0.0
# 24          1  TRANSFER   311685.89       10835.00             0.0
# ...       ...       ...         ...            ...             ...
# 6362615   743  CASH_OUT   339682.13      339682.13             0.0
# 6362616   743  TRANSFER  6311409.28     6311409.28             0.0
# 6362617   743  CASH_OUT  6311409.28     6311409.28             0.0
# 6362618   743  TRANSFER   850002.52      850002.52             0.0
# 6362619   743  CASH_OUT   850002.52      850002.52             0.0
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2                  0.00            0.00        1               0
# 3              21182.00            0.00        1               0
# 15              5083.00        51513.44        0               0
# 19             22425.00            0.00        0               0
# 24              6267.00      2719172.89        0               0
# ...                 ...             ...      ...             ...
# 6362615            0.00       339682.13        1               0
# 6362616            0.00            0.00        1               0
# 6362617        68488.84      6379898.11        1               0
# 6362618            0.00            0.00        1               0
# 6362619      6510099.11      7360101.63        1               0
#
#          errorbalanceOrg  errorbalanceDest
# 2                   0.00      1.810000e+02
# 3                   0.00      2.136300e+04
# 15             213808.94      1.827035e+05
# 19             214605.30      2.377353e+05
# 24             300850.89     -2.401220e+06
# ...                  ...               ...
# 6362615             0.00      0.000000e+00
# 6362616             0.00      6.311409e+06
# 6362617             0.00      1.000000e-02
# 6362618             0.00      8.500025e+05
# 6362619             0.00      9.313226e-10
#
# [2770409 rows x 11 columns]

# %% [markdown]
# ### `how many observations were flagged as Fraud?`

# %%
flagged = df_new[df_new["isFlaggedFraud"] == 1]
flagged_correctly = sum(flagged["isFraud"] == 1)
flagged_wrongly = len(flagged) - flagged_correctly
total = flagged_correctly + flagged_wrongly
print(flagged_correctly," observations were flagged correctly and ", flagged_wrongly, \
      " observations were flagged wrongly for a total of ", total, " flagged observations.")

# Transaction type = Transfer & amount greater than 200, 000 are in the dataset
should_be_flagged = fraud[(fraud["amount"] > 200000) & (fraud["type"] == "TRANSFER")]
print("number of observations that should be flagged: ",len(should_be_flagged))
# Out:
# 16  observations were flagged correctly and  0  observations were flagged wrongly for a total of  16  flagged observations.
# number of observations that should be flagged:  2740

# %% [markdown]
# ### `isFlaggedFraud Feature in Dataset`

# %%
flagged = df_new[df_new['isFlaggedFraud'] == 1]

# %%
flagged
# Out:
#          step      type       amount  oldbalanceOrg  newbalanceOrig  \
# 2736446   212  TRANSFER   4953893.08     4953893.08      4953893.08
# 3247297   250  TRANSFER   1343002.08     1343002.08      1343002.08
# 3760288   279  TRANSFER    536624.41      536624.41       536624.41
# 5563713   387  TRANSFER   4892193.09     4892193.09      4892193.09
# 5996407   425  TRANSFER  10000000.00    19585040.37     19585040.37
# 5996409   425  TRANSFER   9585040.37    19585040.37     19585040.37
# 6168499   554  TRANSFER   3576297.10     3576297.10      3576297.10
# 6205439   586  TRANSFER    353874.22      353874.22       353874.22
# 6266413   617  TRANSFER   2542664.27     2542664.27      2542664.27
# 6281482   646  TRANSFER  10000000.00    10399045.08     10399045.08
# 6281484   646  TRANSFER    399045.08    10399045.08     10399045.08
# 6296014   671  TRANSFER   3441041.46     3441041.46      3441041.46
# 6351225   702  TRANSFER   3171085.59     3171085.59      3171085.59
# 6362460   730  TRANSFER  10000000.00    17316255.05     17316255.05
# 6362462   730  TRANSFER   7316255.05    17316255.05     17316255.05
# 6362584   741  TRANSFER   5674547.89     5674547.89      5674547.89
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2736446             0.0             0.0        1               1
# 3247297             0.0             0.0        1               1
# 3760288             0.0             0.0        1               1
# 5563713             0.0             0.0        1               1
# 5996407             0.0             0.0        1               1
# 5996409             0.0             0.0        1               1
# 6168499             0.0             0.0        1               1
# 6205439             0.0             0.0        1               1
# 6266413             0.0             0.0        1               1
# 6281482             0.0             0.0        1               1
# 6281484             0.0             0.0        1               1
# 6296014             0.0             0.0        1               1
# 6351225             0.0             0.0        1               1
# 6362460             0.0             0.0        1               1
# 6362462             0.0             0.0        1               1
# 6362584             0.0             0.0        1               1
#
#          errorbalanceOrg  errorbalanceDest
# 2736446       4953893.08        4953893.08
# 3247297       1343002.08        1343002.08
# 3760288        536624.41         536624.41
# 5563713       4892193.09        4892193.09
# 5996407      10000000.00       10000000.00
# 5996409       9585040.37        9585040.37
# 6168499       3576297.10        3576297.10
# 6205439        353874.22         353874.22
# 6266413       2542664.27        2542664.27
# 6281482      10000000.00       10000000.00
# 6281484        399045.08         399045.08
# 6296014       3441041.46        3441041.46
# 6351225       3171085.59        3171085.59
# 6362460      10000000.00       10000000.00
# 6362462       7316255.05        7316255.05
# 6362584       5674547.89        5674547.89

# %%
flagged_correctly = sum(flagged.isFraud == 1)
flagged_wrongly = len(flagged) - flagged_correctly
Total = flagged_correctly + flagged_wrongly

print(f'''Flagged
Correctly Flagged: {flagged_correctly}
Wrongly Flagged: {flagged_wrongly}
Total: {Total}
''')
# Out:
# Flagged
# Correctly Flagged: 16
# Wrongly Flagged: 0
# Total: 16

# %%
should_be_flagged = fraud[(fraud["amount"] > 200000) & (fraud["type"] == "TRANSFER")]
print("number of observations that should be flagged: ",len(should_be_flagged))
# Out:
# number of observations that should be flagged:  2740

# %%
should_be_flagged = df[(df.amount > 200000) & (df.type == 'TRANSFER')]
len(should_be_flagged)
# Out:
# 409110

# %%
fraud = fraud.drop("isFlaggedFraud",1)
valid = valid.drop("isFlaggedFraud",1)
df_new = df_new.drop("isFlaggedFraud",1)

# %%
df_new
# Out:
#          step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 2           1  TRANSFER      181.00         181.00             0.0
# 3           1  CASH_OUT      181.00         181.00             0.0
# 15          1  CASH_OUT   229133.94       15325.00             0.0
# 19          1  TRANSFER   215310.30         705.00             0.0
# 24          1  TRANSFER   311685.89       10835.00             0.0
# ...       ...       ...         ...            ...             ...
# 6362615   743  CASH_OUT   339682.13      339682.13             0.0
# 6362616   743  TRANSFER  6311409.28     6311409.28             0.0
# 6362617   743  CASH_OUT  6311409.28     6311409.28             0.0
# 6362618   743  TRANSFER   850002.52      850002.52             0.0
# 6362619   743  CASH_OUT   850002.52      850002.52             0.0
#
#          oldbalanceDest  newbalanceDest  isFraud  errorbalanceOrg  \
# 2                  0.00            0.00        1             0.00
# 3              21182.00            0.00        1             0.00
# 15              5083.00        51513.44        0        213808.94
# 19             22425.00            0.00        0        214605.30
# 24              6267.00      2719172.89        0        300850.89
# ...                 ...             ...      ...              ...
# 6362615            0.00       339682.13        1             0.00
# 6362616            0.00            0.00        1             0.00
# 6362617        68488.84      6379898.11        1             0.00
# 6362618            0.00            0.00        1             0.00
# 6362619      6510099.11      7360101.63        1             0.00
#
#          errorbalanceDest
# 2            1.810000e+02
# 3            2.136300e+04
# 15           1.827035e+05
# 19           2.377353e+05
# 24          -2.401220e+06
# ...                   ...
# 6362615      0.000000e+00
# 6362616      6.311409e+06
# 6362617      1.000000e-02
# 6362618      8.500025e+05
# 6362619      9.313226e-10
#
# [2770409 rows x 10 columns]

# %% [markdown]
# ### `Hence, isFlaggedFraud is not much usefull`

# %% [markdown]
# ### `step feature in dataset`

# %%
bins = 50

valid.hist(column="step",color="green",bins=bins)
plt.xlabel("1 hour time step")
plt.ylabel("# of transactions")
plt.title("# of valid transactions over time")
# Out:
# Text(0.5, 1.0, '# of valid transactions over time')

# %%
bins = 50

fraud.hist(column="step",color="red",bins=bins)
plt.xlabel("1 hour time step")
plt.ylabel("# of transactions")
plt.title("# of valid transactions over time")
# Out:
# Text(0.5, 1.0, '# of valid transactions over time')

# %% [markdown]
# ### `Checking by Days & Weeks`

# %%
num_days = 7
num_hours = 24

fraud_days = fraud['step'] % num_days
fraud_hours = fraud['step'] % num_hours

valid_days = valid['step'] % num_days
valid_hours = valid['step'] % num_hours

# %%
plt.subplot(1, 3, 1)

fraud_days.hist(bins=num_days, color='red')
plt.title('Fraud Transactions by Days')
plt.xlabel('days of week')
plt.ylabel('# of transaction')

plt.subplot(1, 3, 3)

valid_days.hist(bins=num_days, color='green')
plt.title('Valid transactions by Days')
plt.xlabel('days of week')
plt.ylabel('# of transaction')
# Out:
# Text(0, 0.5, '# of transaction')

# %%
plt.subplot(1, 3, 1)

fraud_hours.hist(bins=num_hours, color='red')
plt.title('Fraud Transactions by Days')
plt.xlabel('hours of week')
plt.ylabel('# of transaction')

plt.subplot(1, 3, 3)

valid_hours.hist(bins=num_hours, color='green')
plt.title('Valid transactions by Days')
plt.xlabel('hours of week')
plt.ylabel('# of transaction')
# Out:
# Text(0, 0.5, '# of transaction')

# %%
df1 = df_new.copy()

df1.head()
# Out:
#     step      type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2      1  TRANSFER     181.00          181.0             0.0             0.0
# 3      1  CASH_OUT     181.00          181.0             0.0         21182.0
# 15     1  CASH_OUT  229133.94        15325.0             0.0          5083.0
# 19     1  TRANSFER  215310.30          705.0             0.0         22425.0
# 24     1  TRANSFER  311685.89        10835.0             0.0          6267.0
#
#     newbalanceDest  isFraud  errorbalanceOrg  errorbalanceDest
# 2             0.00        1             0.00             181.0
# 3             0.00        1             0.00           21363.0
# 15        51513.44        0        213808.94          182703.5
# 19            0.00        0        214605.30          237735.3
# 24      2719172.89        0        300850.89        -2401220.0

# %%
df1['HourOfDays'] = np.nan
df1.HourOfDays = df_new.step % 24

df1.head()
# Out:
#     step      type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2      1  TRANSFER     181.00          181.0             0.0             0.0
# 3      1  CASH_OUT     181.00          181.0             0.0         21182.0
# 15     1  CASH_OUT  229133.94        15325.0             0.0          5083.0
# 19     1  TRANSFER  215310.30          705.0             0.0         22425.0
# 24     1  TRANSFER  311685.89        10835.0             0.0          6267.0
#
#     newbalanceDest  isFraud  errorbalanceOrg  errorbalanceDest  HourOfDays
# 2             0.00        1             0.00             181.0           1
# 3             0.00        1             0.00           21363.0           1
# 15        51513.44        0        213808.94          182703.5           1
# 19            0.00        0        214605.30          237735.3           1
# 24      2719172.89        0        300850.89        -2401220.0           1

# %%
print(f'''Stats on the amounts moved in Fraud Transactions: 
{ fraud.amount.describe() }

Stats on the amounts moved in Valid Transactions:
{ valid.amount.describe() }
''')
# Out:
# Stats on the amounts moved in Fraud Transactions:
# count    8.213000e+03
# mean     1.467967e+06
# std      2.404253e+06
# min      0.000000e+00
# 25%      1.270913e+05
# 50%      4.414234e+05
# 75%      1.517771e+06
# max      1.000000e+07
# Name: amount, dtype: float64
#
# Stats on the amounts moved in Valid Transactions:
# count    2.762196e+06
# mean     3.141155e+05
# std      8.771441e+05
# min      1.000000e-02
# 25%      8.290823e+04
# 50%      1.710345e+05
# 75%      3.059942e+05
# max      9.244552e+07
# Name: amount, dtype: float64

# %%
alpha = 0.3
fig, ax = plt.subplots()

valid.plot.scatter(x='step', y='amount', color='green', alpha=alpha, ax=ax, label='Valid Transactions')

plt.title('1 hour timestep vs amount')
plt.xlabel('1 hour time-step')
plt.ylabel('amount moved in transaction')
plt.legend(loc='upper right')

plt.axhline(y=10000000)
plt.show()

print(f'''Proportion of transactions where the amount moved is greater than 10 million: \
{ len(df_new[df_new.amount > 10000000]) / len(df_new) }
''')
# Out:
# Proportion of transactions where the amount moved is greater than 10 million: 0.0008818192548464865

# %%
alpha = 0.3
fig, ax = plt.subplots()

fraud.plot.scatter(x='step', y='amount', color='red', alpha=alpha, ax=ax, label='Fraud Transactions')

plt.title('1 hour timestep vs amount')
plt.xlabel('1 hour time-step')
plt.ylabel('amount moved in transaction')
plt.legend(loc='upper right')

plt.axhline(y=10000000)
plt.show()

print(f'''Proportion of transactions where the amount moved is greater than 10 million: \
{ len(df_new[df_new.amount > 10000000]) / len(df_new) }
''')
# Out:
# Proportion of transactions where the amount moved is greater than 10 million: 0.0008818192548464865

# %%
alpha = 0.3
fig,ax = plt.subplots()

valid.plot.scatter(x="step",y="amount",color="green",alpha=alpha,ax=ax,label="Valid Transactions")
fraud.plot.scatter(x="step",y="amount",color="red",alpha=alpha,ax=ax, label="Fraudulent Transactions")

plt.title("1 hour timestep vs amount")
plt.xlabel("1 hour time-step")
plt.ylabel("amount moved in transaction")
plt.legend(loc="upper right")

plt.axhline(y=10000000)
plt.show()


print(f'''Proportion of transactions where the amount moved is greater than 10 million: \
{ len(df_new[df_new.amount > 10000000]) / len(df_new) }
''')
# Out:
# Proportion of transactions where the amount moved is greater than 10 million: 0.0008818192548464865

# %% [markdown]
# ### `Transaction with amount greater than 10,000,000 are valid is less than 0.01%`

# %% [markdown]
# ## `One Hot Encoding`

# %%
dataset = pd.get_dummies(df_new,prefix=['type'])

# %%
pd.DataFrame.head(dataset)
# Out:
#     step     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2      1     181.00          181.0             0.0             0.0
# 3      1     181.00          181.0             0.0         21182.0
# 15     1  229133.94        15325.0             0.0          5083.0
# 19     1  215310.30          705.0             0.0         22425.0
# 24     1  311685.89        10835.0             0.0          6267.0
#
#     newbalanceDest  isFraud  errorbalanceOrg  errorbalanceDest  type_CASH_OUT  \
# 2             0.00        1             0.00             181.0              0
# 3             0.00        1             0.00           21363.0              1
# 15        51513.44        0        213808.94          182703.5              1
# 19            0.00        0        214605.30          237735.3              0
# 24      2719172.89        0        300850.89        -2401220.0              0
#
#     type_TRANSFER
# 2               1
# 3               0
# 15              0
# 19              1
# 24              1

# %% [markdown]
# ## `Splitting Dataset`

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop("isFraud",1)
y = dataset.isFraud
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## `Normalizing Dataset`

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # `Model`

# %%
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier, plot_importance
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, \
                            classification_report, hamming_loss, roc_curve, auc
import pickle

# %% [markdown]
# ### `Accuracy`

# %%
def Accuracy( y_train, y_test, y_pred, y_pred_test):
    return f'''Accuracy:
TRAIN: {accuracy_score(y_train, y_pred)}
TEST:  {accuracy_score(y_test, y_pred_test)}

Balanced Accuracy:
TRAIN: {balanced_accuracy_score(y_train, y_pred)}
TEST:  {balanced_accuracy_score(y_test, y_pred_test)}
'''

# %% [markdown]
# ### `Confusion Matrix`

# %%
def ConfusionMatrix( y_train, y_test, y_pred, y_pred_test):
    return f'''Confusion Matrix
Train:
{confusion_matrix(y_train, y_pred)}
Test:
{confusion_matrix(y_test, y_pred_test)}
'''

# %% [markdown]
# ### `Classification Report`

# %%
def ClassificationReport( y_train, y_test, y_pred, y_pred_test):
    return f'''\tClassification Report
Train:
{classification_report(y_train, y_pred)}
Test:
{classification_report(y_test, y_pred_test)}
'''

# %% [markdown]
# ### `ROC & AUC`

# %%
def roc_auc( y_train, y_test, y_pred, y_pred_test):
    fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_pred)
    fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_pred_test)
    
    roc_train = auc(fpr_train, tpr_train)
    roc_test = auc(fpr_test, tpr_train)

    print(f'''\tArea Under Curve
    Train: {roc_train}
    Test:  {roc_test}scaler.transform
    ''')
    
    fig, ax = plt.subplots(figsize=(7.5,7.5))

    plt.plot(fpr_train, tpr_train, label='ROC Curve Train (AUC = %0.2f)'%(roc_train))
    plt.plot(fpr_test, tpr_test, label='ROC Curve Test (AUC = %0.2f)'%(roc_test))

    plt.plot([0, 1], [0, 1], linestyle='--', color='red', label='Random Classifier')   
    plt.plot([0, 0, 1], [0, 1, 1], linestyle=':', color='green', label='Perfect Classifier')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### `Pickel Dump`

# %%
def Dump(pipeline, model_name):
    pickle.dump(pipeline, open(model_name, 'wb'))

# %% [markdown]
# ## `Multi Layer perceptron(MLP) ANN`

# %%
ncol = len(X.columns)
hidden_layers = (ncol, ncol, ncol)

# %% [markdown]
# ## `Make Pipeline`

# %% [markdown]
# ### `MLP Adam`

# %%
# mlp adam
pipeline_mlp_adam = make_pipeline(StandardScaler(), \
            MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=1000, solver='adam', random_state=42))

# %%
pipeline_mlp_adam.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpclassifier',
#                  MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000,
#                                random_state=42))])

# %%
y_pred_adam = pipeline_mlp_adam.predict(X_train)

y_pred_test_adam = pipeline_mlp_adam.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_adam, y_pred_test_adam))

print(ConfusionMatrix( y_train, y_test, y_pred_adam, y_pred_test_adam))

print(ClassificationReport( y_train, y_test, y_pred_adam, y_pred_test_adam))

print(roc_auc( y_train, y_test, y_pred_adam, y_pred_test_adam))
# Out:
# Accuracy:
# TRAIN: 0.9993478698203778
# TEST:  0.9993603839428937
#
# Balanced Accuracy:
# TRAIN: 0.912455901660825
# TEST:  0.9195245777436558
#
# Confusion Matrix
# Train:
# [[2071358     275]
#  [   1080    5093]]
# Test:
# [[690448    115]
#  [   328   1712]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       0.95      0.83      0.88      6173
#
#     accuracy                           1.00   2077806
#    macro avg       0.97      0.91      0.94   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       0.94      0.84      0.89      2040
#
#     accuracy                           1.00    692603
#    macro avg       0.97      0.92      0.94    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 0.912455901660825
#     Test:  0.9124390090272658scaler.transform
# None

# %%
Dump(pipeline_mlp_adam, 'model_mlp_adam.pkl')

# %% [markdown]
# ### `MLP lbfgs`

# %%
# mlp lbfgs
pipeline_mlp_lbfgs = make_pipeline(StandardScaler(), \
            MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=200, solver='lbfgs', random_state=42))

# %%
pipeline_mlp_lbfgs.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpclassifier',
#                  MLPClassifier(hidden_layer_sizes=(10, 10, 10), random_state=42,
#                                solver='lbfgs'))])

# %%
y_pred_lbfgs = pipeline_mlp_lbfgs.predict(X_train)

y_pred_test_lbfgs = pipeline_mlp_lbfgs.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_lbfgs, y_pred_test_lbfgs))

print(ConfusionMatrix( y_train, y_test, y_pred_lbfgs, y_pred_test_lbfgs))

print(ClassificationReport( y_train, y_test, y_pred_lbfgs, y_pred_test_lbfgs))

print(roc_auc( y_train, y_test, y_pred_lbfgs, y_pred_test_lbfgs))
# Out:
# Accuracy:
# TRAIN: 0.9992756782875784
# TEST:  0.999253540628614
#
# Balanced Accuracy:
# TRAIN: 0.8915845113877323
# TEST:  0.8967442169877133
#
# Confusion Matrix
# Train:
# [[2071466     167]
#  [   1338    4835]]
# Test:
# [[690467     96]
#  [   421   1619]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       0.97      0.78      0.87      6173
#
#     accuracy                           1.00   2077806
#    macro avg       0.98      0.89      0.93   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       0.94      0.79      0.86      2040
#
#     accuracy                           1.00    692603
#    macro avg       0.97      0.90      0.93    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 0.8915845113877322
#     Test:  0.8915553092522556scaler.transform
# None

# %%
Dump(pipeline_mlp_lbfgs, 'model_mlp_lbfgs.pkl')

# %% [markdown]
# ### `MLP sgd`

# %%
# mlp sgd
pipeline_mlp_sgd = make_pipeline(StandardScaler(), \
            MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=1000, solver='sgd', random_state=42))

# %%
pipeline_mlp_sgd.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpclassifier',
#                  MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000,
#                                random_state=42, solver='sgd'))])

# %%
y_pred_sgd = pipeline_mlp_sgd.predict(X_train)

y_pred_test_sgd = pipeline_mlp_sgd.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_sgd, y_pred_test_sgd))

print(ConfusionMatrix( y_train, y_test, y_pred_sgd, y_pred_test_sgd))

print(ClassificationReport( y_train, y_test, y_pred_sgd, y_pred_test_sgd))

print(roc_auc( y_train, y_test, y_pred_sgd, y_pred_test_sgd))
# Out:
# Accuracy:
# TRAIN: 0.9988699618732452
# TEST:  0.9989214600572045
#
# Balanced Accuracy:
# TRAIN: 0.8276641397820139
# TEST:  0.8342623181602349
#
# Confusion Matrix
# Train:
# [[2071412     221]
#  [   2127    4046]]
# Test:
# [[690492     71]
#  [   676   1364]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       0.95      0.66      0.78      6173
#
#     accuracy                           1.00   2077806
#    macro avg       0.97      0.83      0.89   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       0.95      0.67      0.79      2040
#
#     accuracy                           1.00    692603
#    macro avg       0.97      0.83      0.89    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 0.827664139782014
#     Test:  0.8276660720155758scaler.transform
# None

# %%
Dump(pipeline_mlp_sgd, 'model_mlp_sgd.pkl')

# %% [markdown]
# ## `Decision Tree Classifier`

# %%
pipeline_decisiontree = make_pipeline(StandardScaler(), DecisionTreeClassifier())

# %%
pipeline_decisiontree.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
y_pred_decisiontree = pipeline_decisiontree.predict(X_train)

y_pred_test_decisiontree = pipeline_decisiontree.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_decisiontree, y_pred_test_decisiontree))

print(ConfusionMatrix( y_train, y_test, y_pred_decisiontree, y_pred_test_decisiontree))

print(ClassificationReport( y_train, y_test, y_pred_decisiontree, y_pred_test_decisiontree))

print(roc_auc( y_train, y_test, y_pred_decisiontree, y_pred_test_decisiontree))
# Out:
# Accuracy:
# TRAIN: 1.0
# TEST:  0.9999653481142877
#
# Balanced Accuracy:
# TRAIN: 1.0
# TEST:  0.9970501349666014
#
# Confusion Matrix
# Train:
# [[2071633       0]
#  [      0    6173]]
# Test:
# [[690551     12]
#  [    12   2028]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       1.00      1.00      1.00      6173
#
#     accuracy                           1.00   2077806
#    macro avg       1.00      1.00      1.00   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       0.99      0.99      0.99      2040
#
#     accuracy                           1.00    692603
#    macro avg       1.00      1.00      1.00    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 1.0
#     Test:  0.9999913114371897scaler.transform
# None

# %%
Dump(pipeline_decisiontree, 'model_decisiontree.pkl')

# %% [markdown]
# ## `Random Forest Classifier`

# %%
pipeline_randomforest = make_pipeline(StandardScaler(), \
                         RandomForestClassifier())

# %%
pipeline_randomforest.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
y_pred_randomforest = pipeline_randomforest.predict(X_train)

y_pred_test_randomforest = pipeline_randomforest.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_randomforest, y_pred_test_randomforest))

print(ConfusionMatrix( y_train, y_test, y_pred_randomforest, y_pred_test_randomforest))

print(ClassificationReport( y_train, y_test, y_pred_randomforest, y_pred_test_randomforest))

print(roc_auc( y_train, y_test, y_pred_randomforest, y_pred_test_randomforest))
# Out:
# Accuracy:
# TRAIN: 1.0
# TEST:  0.9999812302285725
#
# Balanced Accuracy:
# TRAIN: 1.0
# TEST:  0.9970580994825109
#
# Confusion Matrix
# Train:
# [[2071633       0]
#  [      0    6173]]
# Test:
# [[690562      1]
#  [    12   2028]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       1.00      1.00      1.00      6173
#
#     accuracy                           1.00   2077806
#    macro avg       1.00      1.00      1.00   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       1.00      0.99      1.00      2040
#
#     accuracy                           1.00    692603
#    macro avg       1.00      1.00      1.00    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 1.0
#     Test:  0.9999992759530991scaler.transform
# None

# %%
Dump(pipeline_randomforest, 'model_randomforest.pkl')

# %% [markdown]
# ## `XGBoost`

# %%
from xgboost import XGBClassifier

# %%
pipeline_xgb = make_pipeline(StandardScaler(), XGBClassifier())

# %%
pipeline_xgb.fit(X_train, y_train)
# Out:
# [17:03:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, enable_categorical=False,
#                                gamma=0, gpu_id=-1, importance_type=None,
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=6, num_parallel_tree=1, predictor='auto',
#                                random_state=0, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=1, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
y_pred_xgb = pipeline_xgb.predict(X_train)

y_pred_test_xgb = pipeline_xgb.predict(X_test)

print(Accuracy( y_train, y_test, y_pred_xgb, y_pred_test_xgb))

print(ConfusionMatrix( y_train, y_test, y_pred_xgb, y_pred_test_xgb))

print(ClassificationReport( y_train, y_test, y_pred_xgb, y_pred_test_xgb))

print(roc_auc( y_train, y_test, y_pred_xgb, y_pred_test_xgb))
# Out:
# Accuracy:
# TRAIN: 0.9999942246773761
# TEST:  0.9999812302285725
#
# Balanced Accuracy:
# TRAIN: 0.9990280252713429
# TEST:  0.9973024734748257
#
# Confusion Matrix
# Train:
# [[2071633       0]
#  [     12    6161]]
# Test:
# [[690561      2]
#  [    11   2029]]
#
# 	Classification Report
# Train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2071633
#            1       1.00      1.00      1.00      6173
#
#     accuracy                           1.00   2077806
#    macro avg       1.00      1.00      1.00   2077806
# weighted avg       1.00      1.00      1.00   2077806
#
# Test:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    690563
#            1       1.00      0.99      1.00      2040
#
#     accuracy                           1.00    692603
#    macro avg       1.00      1.00      1.00    692603
# weighted avg       1.00      1.00      1.00    692603
#
#
# 	Area Under Curve
#     Train: 0.9990280252713429
#     Test:  0.9990265771775412scaler.transform
# None

# %%
Dump(pipeline_xgb, 'model_xgb.pkl')
